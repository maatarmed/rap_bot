# %%
from pymongo import MongoClient
import json
import requests
import urllib.request
import urllib.parse
from bs4 import BeautifulSoup
import re
import os

# DB connexion
global client
client = MongoClient(port=27017)
global db
db = client.GeniusScrappingProject

API_BASE = "https://api.genius.com"
API_CLIENT_ACCESS_TOKEN = "w7XemCkBJW-a0eT5RZ3bjHKt9-fr-v0RYBYS4iQ_9CtY-uvbJomzCpuqoonzw6jM"


def add_songs(songs):
	if isinstance(songs, list):
		for song, _ in enumerate(songs):
			print (song)
			entry = {
				'id' : int(songs[song]['id']),
				'title' : songs[song]['title'],
				'primary_artist' : {
					'id' : songs[song]['primary_artist']['id'],
					'name' : songs[song]['primary_artist']['name'],
					'url' : songs[song]['primary_artist']['url'],
					'is_verified' : songs[song]['primary_artist']['is_verified']
					},
				'url' : songs[song]['url']
				}
			print(songs[song]['album'])
			if songs[song]['album']:
				entry['album'] = {
					'id': songs[song]['album']['id'], 
					'full_title': songs[song]['album']['full_title'], 
					'name': songs[song]['album']['name'], 
					'artist': songs[song]['album']['artist']['id']
					}
			if len(songs[song]['featured_artists']) > 0:
				featured_artists = list()
				for artist in songs[song]['featured_artists']:
					art = {
						'id' : artist['id'],
						'name' : artist['name']
						}
					featured_artists.append(art)
				entry['featured_artists'] = featured_artists
			#Step 3: Insert Artist into MongoDB via isnert_one
			db.songs.insert_one(entry)
			print('songs {} added with success'.format(songs[song]['title']))
	else:
		entry = {
			'id' : int(songs['id']),
			'title' : songs['title'],
			'primary_artist' : {
				'id' : songs['primary_artist']['id'],
				'name' : songs['primary_artist']['name'],
				'url' : songs['primary_artist']['url'],
				'is_verified' : songs['primary_artist']['is_verified']
				},
			'url' : songs['url'],
			'album': {
				'id': songs['album']['id'], 
				'full_title': songs['album']['full_title'], 
				'name': songs['album']['name'], 
				'artist': songs['album']['artist']['id']
				}
			}
		if len(songs['featured_artists']) > 0:
			featured_artists = list()
			for artist in songs['featured_artists']:
				art = {
					'id' : artist['id'],
					'name' : artist['name']
					}
				featured_artists.append(art)
		entry['featured_artists'] = featured_artists

		db.songs.insert_one(entry)
		print('songs {} added with success'.format(songs['title']))

# %%
def get_json(path, params=None, headers=None):
    """
    Generate Request URL and Get response object from querying the genius API

    Args:
        path (string): url to get data from
        params (optional): request parameters. Defaults to None.
        headers (optional): check if Authorization existes create one otherwise. Defaults to None.

    Returns:
        json : request result
    """
    # Generate request URL
    requrl = '/'.join([API_BASE, path])
    token = "Bearer {}".format(API_CLIENT_ACCESS_TOKEN)
    if headers:
        headers['Authorization'] = token
    else:
        headers = {"Authorization": token}
    # Get response object from querying genius api
    response = requests.get(url=requrl, params=params, headers=headers)
    response.raise_for_status()
    return response.json()

# %%
def get_artist_songs_id(artist_id):
    """
    Retrieve all the songs IDs of an artist

    Args:
        artist_id (Int): THe artist's ID

    Returns:
        List: all the songs that the artist is the primary one
    """
    #Get all the song id from an artist.#
    current_page = 1
    next_page = True
    songs = []  # to store final song ids

    while next_page:
        path = "artists/{}/songs/".format(artist_id)
        params = {'page': current_page}  # the current page
        data = get_json(path=path, params=params)  # get json of songs
        page_songs = data['response']['songs']
        if page_songs:
            # Add all the songs of current page
            songs += page_songs
            # Increment current_page value for next loop
            current_page += 1
            print("Page {} finished scraping".format(current_page))
            # If you don't wanna wait too long to scrape, un-comment this
            # if current_page == 2:
            #   break
        else:
            # If page_songs is empty, quit
            next_page = False

    print("Song id were scraped from {} pages".format(current_page))

    # Get all the song ids, excluding not-primary-artist songs.
    songs = [song["id"] for song in songs]
    # if song["primary_artist"]["id"] == artist_id

    return songs

# %%
def search(query, typee='artist'):
    """
    This is a one function to get data through the Genius API

    Args:
        typee (string) : takes one of the following values : artist - song
        query (string / int) : string when type search, int otherwise

    Returns:
        dict: the full data
    """
    if typee == 'artist' or typee == 'song':
        assert str(query).isdecimal()
        url = '{0}s/{1}'.format(typee, query)
        request = get_json(url)
        data = request['response'][typee]
    else:
        url = 'search?access_token={0}&q={1}'.format(API_CLIENT_ACCESS_TOKEN, query)
        request = get_json(url)
        data = request['response']['hits']
    return data

# %%
songs = get_artist_songs_id(56)
# Out:
# Page 2 finished scraping
# Page 3 finished scraping
# Page 4 finished scraping
# Page 5 finished scraping
# Page 6 finished scraping
# Page 7 finished scraping
# Page 8 finished scraping
# Page 9 finished scraping
# Page 10 finished scraping
# Page 11 finished scraping
# Page 12 finished scraping
# Page 13 finished scraping
# Page 14 finished scraping
# Page 15 finished scraping
# Page 16 finished scraping
# Page 17 finished scraping
# Page 18 finished scraping
# Page 19 finished scraping
# Page 20 finished scraping
# Page 21 finished scraping
# Page 22 finished scraping
# Page 23 finished scraping
# Page 24 finished scraping
# Page 25 finished scraping
# Page 26 finished scraping
# Page 27 finished scraping
# Page 28 finished scraping
# Page 29 finished scraping
# Page 30 finished scraping
# Page 31 finished scraping
# Page 32 finished scraping
# Page 33 finished scraping
# Page 34 finished scraping
# Page 35 finished scraping
# Page 36 finished scraping
# Page 37 finished scraping
# Page 38 finished scraping
# Page 39 finished scraping
# Page 40 finished scraping
# Page 41 finished scraping
# Page 42 finished scraping
# Page 43 finished scraping
# Page 44 finished scraping
# Page 45 finished scraping
# Page 46 finished scraping
# Page 47 finished scraping
# Page 48 finished scraping
# Song id were scraped from 48 pages

# %%
if isinstance(songs, list):
  for song_id in songs:
      song = search(song_id, 'song')
      print(song_id)
      entry = {
          'id' : int(song['id']),
          'title' : song['title'],
          'primary_artist' : {
              'id' : song['primary_artist']['id'],
		      'name' : song['primary_artist']['name'],
		      'url' : song['primary_artist']['url'],
	          'is_verified' : song['primary_artist']['is_verified']
		      },
		  'url' : song['url']
		  }
      if song['album']:
          entry['album'] = {
              'id': song['album']['id'], 
              'full_title': song['album']['full_title'], 
              'name': song['album']['name'], 
              'artist': song['album']['artist']['id']
              }
      if song['release_date']:
          entry['release_date'] = song['release_date']
      if len(song['featured_artists']) > 0:
          featured_artists = list()
          for artist in song['featured_artists']:
              art = {
                  'id' : artist['id'],
                  'name' : artist['name']
                  }
              featured_artists.append(art)
          entry['featured_artists'] = featured_artists
      db.songs.insert_one(entry)
      print('songs {} added with success'.format(song['title']))
# Out:
# gs Not For Radio added with success
# 34796
# songs Not Going Back added with success
# 2128
# songs Nothing Lasts Forever added with success
# 63880
# songs Nothing to Lose added with success
# 120137
# songs NYC added with success
# 5913057
# songs NYC added with success
# 3721775
# songs NYCHA added with success
# 4307730
# songs NY Se Mumbai added with success
# 89
# songs N.Y. State of Mind added with success
# 3667833
# songs N.Y. State Of Mind (Live) added with success
# 1066
# songs N.Y. State of Mind, Pt. II added with success
# 86736
# songs N.Y. State of Mind, Pt. III added with success
# 214900
# songs NY State of Mind Q-Ball Mix added with success
# 603152
# songs Oh-Oh, Yeah-Yea added with success
# 5221305
# songs Old Town Road / Rodeo (Live at the 62nd Grammy Awards) added with success
# 454
# songs One Love added with success
# 357538
# songs One Love (10th Anniversary Remix) added with success
# 5360112
# songs One Love (J. Period ReFix) added with success
# 405712
# songs One Love (LG Main Mix) added with success
# 3667838
# songs One Love (Live) added with success
# 405018
# songs One Love (One L Main Mix) added with success
# 1803700
# songs One Love (Remix) added with success
# 2494006
# songs One Mic added with success
# 490
# songs One Mic added with success
# 57596
# songs One Mic added with success
# 5236108
# songs One Mic added with success
# 5534887
# songs One Mic added with success
# 4788396
# songs One Mic (American Epic Session) added with success
# 34858
# songs One Mic (Remix) added with success
# 5763498
# songs One Mike added with success
# 34853
# songs One Never Knows added with success
# 2371931
# songs One of Us added with success
# 34856
# songs One on One added with success
# 27517
# songs One Plus One added with success
# 731
# songs One Time 4 Your Mind added with success
# 3667839
# songs One Time 4 Your Mind (Live) added with success
# 3461
# songs On the Real added with success
# 53263
# songs On The Real (original) added with success
# 3085050
# songs On The Road Again added with success
# 34870
# songs Oochie Wally (Remix) added with success
# 104966
# songs Open Letter to Young Warriors in Chicago (Sep. 2009) added with success
# 54736
# songs Outro added with success
# 3547368
# songs Outro added with success
# 2957
# songs Outty 5000 added with success
# 5913065
# songs Papers 2 added with success
# 141907
# songs Pasadena (Skit) added with success
# 2528
# songs Patience (Sabali) added with success
# 379695
# songs Peace God added with success
# 4633065
# songs Phone Messages (Part 1) added with success
# 4064
# songs Phone Tap added with success
# 674531
# songs Piece of Mind added with success
# 31974
# songs Play Me added with success
# 51699
# songs Play On Playa added with success
# 1814247
# songs Play On Playa [Clean] added with success
# 34817
# songs Poppa Was a Playa added with success
# 35321
# songs Popular Thug (Clones Version) added with success
# 4318
# songs POR TRAS DO MEU SSORIZO added with success
# 2745
# songs Power Paper Pussy added with success
# 3019513
# songs Powers That Be added with success
# 34804
# songs Pray added with success
# 34887
# songs Proclamation (Nigger Hatred) added with success
# 4556309
# songs Project Kids (Skit) added with success
# 34890
# songs Project Roach added with success
# 34829
# songs Project Windows added with success
# 658
# songs Purple added with success
# 34792
# songs Pussy Killz (Bonus Disc) added with success
# 4672357
# songs QueensBridge Politics added with success
# 40849
# songs Queens Day added with success
# 17002
# songs Queensfinest added with success
# 917
# songs Queens Get the Money added with success
# 156184
# songs Queens Shit added with success
# 4672354
# songs Queens Wolf added with success
# 11624
# songs Quick To Back Down added with success
# 34830
# songs Quiet Niggas added with success
# 2347480
# songs Rain added with success
# 1796
# songs Rap Game / Crack Game added with success
# 436241
# songs Rare/Unreleased Tracks & Freestyles From Pre-Illmatic To The Present added with success
# 78863
# songs Reach Out added with success
# 381184
# songs Ready or Not added with success
# 39183
# songs Real Niggas added with success
# 34762
# songs Reason added with success
# 517612
# songs Record Report Albums: Nas - Illmatic added with success
# 58251
# songs Re:Generation added with success
# 92238
# songs Regeneration (Remix) added with success
# 70973
# songs Re:Generation Remix added with success
# 34767
# songs Remember the Times added with success
# 2878018
# songs Remember the Times (Intro) added with success
# 2012385
# songs Remember The Times (Intro) - Explicit Album Version added with success
# 4882310
# songs Renta added with success
# 5869607
# songs Replace Me added with success
# 704
# songs Represent added with success
# 3667840
# songs Represent (Live) added with success
# 329360
# songs Resistance added with success
# 4317
# songs Respiração do amor fértil added with success
# 34771
# songs Rest of My Life added with success
# 201999
# songs Resurrection (Cypher) added with success
# 34786
# songs Revolutionary Warfare added with success
# 631
# songs Rewind added with success
# 5032
# songs Rich and Black added with success
# 4968951
# songs Rich Niggas added with success
# 34857
# songs Rise & Fall added with success
# 251686
# songs Rise Up Shepherd and Follow added with success
# 2408
# songs Road to Zion added with success
# 5207604
# songs Rodeo (Remix) added with success
# 2894621
# songs Romeo must die added with success
# 78872
# songs Roses added with success
# 379446
# songs Rough Around The Edges added with success
# 4672349
# songs Royalty added with success
# 5937
# songs Rule added with success
# 2836349
# songs Rule The World (I Came From The City) added with success
# 5360097
# songs Run New York (J. Period ReFix) added with success
# 68614
# songs Running added with success
# 1165937
# songs Salute Me added with success
# 34842
# songs Salute Me (The General) added with success
# 34859
# songs Secret Agent Man added with success
# 3547363
# songs Seen It All (Green Mix) added with success
# 3139
# songs Sekou Story added with success
# 39189
# songs Self Conscience added with success
# 8776
# songs Serious added with success
# 34860
# songs Shakedown Remix added with success
# 2863267
# songs She Don’t Really Care_1 Luv added with success
# 32213
# songs She Don’t (Remix) added with success
# 401852
# songs Shine On added with success
# 884
# songs Shoot ’Em Up added with success
# 2358
# songs Shootouts added with success
# 5322024
# songs Shorter* added with success
# 69653
# songs Should You Sell Your Company? added with success
# 24028
# songs Show Discipline added with success
# 3469
# songs Silent Murder added with success
# 3780010
# songs Simple Things added with success
# 32788
# songs Sincerity added with success
# 34863
# songs Sinful Living added with success
# 3012635
# songs Sintonias added with success
# 11622
# songs Situations added with success
# 1784037
# songs Skit added with success
# 32793
# songs Slow Down (Remix) added with success
# 4179
# songs Sly Fox added with success
# 3470
# songs Small World added with success
# 2213509
# songs Smith & Wesson references in Hip-Hop added with success
# 34881
# songs Smokin’ added with success
# 53395
# songs Snitch Alibi added with success
# 1574525
# songs So Fresh added with success
# 966422
# songs So High added with success
# 4267931
# songs Soldier Survivors added with success
# 16451
# songs Some of ’Em added with success
# 34828
# songs Some of Us Have Angels added with success
# 904614
# songs Something added with success
# 89941
# songs Something from Nothing Art of Rap Freestyle added with success
# 708327
# songs Something to Believe In added with success
# 34799
# songs Sometimes I Wonder added with success
# 3894612
# songs Sorry added with success
# 3477814
# songs Sosa Vs. The State added with success
# 26133
# songs Soundtrack to the Streets added with success
# 5869655
# songs Spicy added with success
# 646830
# songs Squeeze added with success
# 3462
# songs Star Wars added with success
# 78868
# songs Stay added with success
# 370406
# songs Stay added with success
# 27506
# songs Stay Chisel added with success
# 27512
# songs Stay Chisel (Solo Version) added with success
# 147348
# songs Stay (Remix) added with success
# 2873323
# songs Stay True added with success
# 1818
# songs Still Dreaming added with success
# 642925
# songs Stillmatic [Credits] added with success
# 3806
# songs Stillmatic (Freestyle) added with success
# 115999
# songs Stillmatic Freestyle (H to the Omo Jay-Z Diss) added with success
# 34883
# songs Stillmatic (The Intro) added with success
# 379672
# songs Story Board added with success
# 214134
# songs Street Dreams added with success
# 4509603
# songs Street Dreams added with success
# 979
# songs Street Dreams added with success
# 34839
# songs Street Dreams (Bonus Verse) added with success
# 34838
# songs Street Dreams (Remix) added with success
# 39188
# songs Street Glory added with success
# 59162
# songs Street Riders added with success
# 34766
# songs Street’s Disciple added with success
# 32750
# songs Streets of New York added with success
# 783283
# songs Streets of New York (City Life) (Unplugged) added with success
# 473
# songs Strong Will Continue added with success
# 516267
# songs Studio (Remix) added with success
# 146
# songs Success added with success
# 3686
# songs Suicide Bounce added with success
# 78865
# songs Summer on Smash added with success
# 213468
# songs Sure Shot Singles: Nasty Nas – Half Time added with success
# 865
# songs Surviving The Times added with success
# 3547366
# songs Surviving the Times (Original) added with success
# 3053
# songs Suspect added with success
# 3060498
# songs Systematic added with success
# 952
# songs Take It in Blood added with success
# 2879082
# songs Take It In Blood added with success
# 3726824
# songs Take It In Blood Pt. 2 added with success
# 34865
# songs Tales From the Hood added with success
# 5913066
# songs Talkin Loud added with success
# 119156
# songs Talk Of New York added with success
# 4672348
# songs Tanasia added with success
# 39191
# songs Teenage Thug added with success
# 1035092
# songs Teenage Thug added with success
# 2466399
# songs Tell Your Friends (MET Gala Remix) added with success
# 5674
# songs Testify added with success
# 32866
# songs Thank God I Found You (Make It Last Remix) added with success
# 6038120
# songs Thank God I Found You (Make It Last Remix Edit) added with success
# 6038118
# songs Thank God I Found You (Make It Last Remix w/o Rap) added with success
# 3705721
# songs The 2 added with success
# 4672352
# songs The Art of It added with success
# 4968941
# songs The Beginning added with success
# 105746
# songs The Big Six (Dead Presidents) added with success
# 78871
# songs The Black Bond added with success
# 34788
# songs The Cross added with success
# 5869650
# songs The Cure added with success
# 5869630
# songs The Definition added with success
# 68291
# songs The Don added with success
# 5913015
# songs The Don- Don Dada Remix (Explicit Version) added with success
# 1999377
# songs The escobar added with success
# 8696
# songs The Essence added with success
# 65818
# songs The Essence (Grammy Remix) added with success
# 34879
# songs The Flyest added with success
# 4968945
# songs The Foulness Pt 1 added with success
# 4968946
# songs The Foulness Pt 3 added with success
# 4968947
# songs The Foulness Pt 4 added with success
# 1336097
# songs The General added with success
# 44347
# songs The General Remix (Salute Me) added with success
# 2211
# songs The Genesis added with success
# 2122236
# songs The genesis - explicit album version added with success
# 3667832
# songs The Genesis (Live) added with success
# 320329
# songs The Get Back added with success
# 2835344
# songs The Get Down: Episode 1 - Where There Is Ruin, There Is Hope For A Treasure added with success
# 2835351
# songs The Get Down: Episode 2 - Seek Those Who Fan Your Flame added with success
# 2835359
# songs The Get Down: Episode 3 - Darkness Is Your Candle added with success
# 2314404
# songs The Ghetto added with success
# 34784
# songs The G.O.D. (Bonus Disc) added with success
# 3199622
# songs The Hated added with success
# 824
# songs Theifs Theme added with success
# 34758
# songs The Makings of a Perfect Bitch added with success
# 6040641
# songs The Mecca added with success
# 2036
# songs The Message added with success
# 71063
# songs The N added with success
# 3050887
# songs The Other Side (The Duet) added with success
# 34825
# songs The Outcome added with success
# 23990
# songs The Pledge Remix added with success
# 34827
# songs The Prediction added with success
# 3944762
# songs “The Price i Pay To See My Son” - Open Letter via Instagram added with success
# 388535
# songs The Prophecy added with success
# 158544
# songs The Saints added with success
# 578476
# songs The Scientist added with success
# 34764
# songs These Are Our Heroes added with success
# 567712
# songs The Season added with success
# 560335
# songs The Season added with success
# 34864
# songs The Second Coming added with success
# 3466
# songs The Set Up added with success
# 2441118
# songs The Sickness added with success
# 4968949
# songs The State added with success
# 375264
# songs The Stretch Armstrong and Bobbito Show on WKCR October 28, 1993 added with success
# 733311
# songs The Success added with success
# 35028
# songs The Ultimate High added with success
# 1809452
# songs The Ultimate High added with success
# 35038
# songs The Ultimate High (LP Version) added with success
# 3184752
# songs The W (Credits) added with success
# 5682
# songs The World added with success
# 109
# songs The World Is Yours added with success
# 357508
# songs The World Is Yours (10th Anniversary Remix) added with success
# 3667835
# songs The World Is Yours (Live) added with success
# 34755
# songs The World Is Yours (Tip Mix) added with success
# 405767
# songs The World Is Yours (Tip Mix) [DUPE] added with success
# 686
# songs Thief’s Theme added with success
# 34769
# songs Thief’s Theme Remix added with success
# 2827704
# songs This Bitter Land added with success
# 5941421
# songs This Is Nas added with success
# 78675
# songs This Thing of Ours added with success
# 4516818
# songs Thriving added with success
# 2161410
# songs Throw Up Ya Gunz added with success
# 4297003
# songs Thug Mansion (DJ Green Lantern Remix) added with success
# 25108
# songs Thug Poet added with success
# 5892194
# songs Thugs Calm Down added with success
# 6564
# songs Thugz Mansion- Nas Acoustic added with success
# 34790
# songs Thugz Mansion (N.Y.) added with success
# 548858
# songs Thugz Mansion Remix added with success
# 34785
# songs Thugz Mirror Freestyle (Bonus Disc) added with success
# 136932
# songs Tick Tock added with success
# 7815
# songs Tick Tock added with success
# 5869609
# songs Til the War Is Won added with success
# 8717
# songs Time added with success
# 30301
# songs To My added with success
# 7042
# songs Too Hot added with success
# 235766
# songs Too Late added with success
# 900
# songs Too Many Rappers added with success
# 695804
# songs Too Many Rappers (New Reactionaries Version) added with success
# 25944
# songs Too Much for Me added with success
# 1814146
# songs Too Much For Me added with success
# 133645
# songs Top Down added with success
# 3038
# songs Topless added with success
# 5332134
# songs Topless added with success
# 3165698
# songs Topless (Original Version) added with success
# 121833
# songs Topless (Remix) added with success
# 3237
# songs Tribes at War added with success
# 62989
# songs Triple Beam Dreams added with success
# 49586
# songs Triple Threat added with success
# 449813
# songs Troubeaux added with success
# 78874
# songs Trust added with success
# 1414281
# songs Turn It Out added with success
# 20290
# songs Turn Up the Mic added with success
# 131642
# songs Turn Up The Mics (Remix) added with success
# 5573598
# songs Twenty Wheels (Blend) added with success
# 11621
# songs Twilight added with success
# 34768
# songs U.B.R. (Unauthorized Biography of Rakim) added with success
# 34816
# songs U Gotta Love It added with success
# 5864557
# songs Ultra Black added with success
# 54820
# songs Understanding added with success
# 2842
# songs Undying Love added with success
# 5389928
# songs Until I Met You added with success
# 4180
# songs Untitled added with success
# 19928
# songs Untouchable added with success
# 4294790
# songs Uptown [Broken Windows] added with success
# 1539
# songs Usual Suspects added with success
# 34868
# songs U Wanna Be Me added with success
# 2110297
# songs U wanna be me - soundtrack version added with success
# 649517
# songs Veni Vidi Vici added with success
# 931
# songs Verbal Intercourse added with success
# 4880158
# songs Verbal Intercourse 2006 (Mick Boogie Mix) added with success
# 4672342
# songs Vernon Family added with success
# 17371
# songs Victory added with success
# 29540
# songs Virgo added with success
# 1819744
# songs Virgo (alternate version) added with success
# 44247
# songs Wake Up Show Anthem (1994) added with success
# 3611425
# songs Walk Thru added with success
# 1266805
# songs Wanna Be Me added with success
# 1448159
# songs Wanna Play added with success
# 34801
# songs Wanna Play (Rough?) added with success
# 18512
# songs Want It added with success
# 34772
# songs War added with success
# 17035
# songs War added with success
# 4672351
# songs War Against Love added with success
# 2869871
# songs War (Birth Of A Nation) added with success
# 34869
# songs War Is Necessary added with success
# 3565841
# songs Warm It Up added with success
# 705712
# songs War Remix added with success
# 34787
# songs Warrior Song added with success
# 2913
# songs Watch Dem Niggas added with success
# 2342268
# songs We Are added with success
# 454728
# songs We Dem Boyz (Remix) added with success
# 468918
# songs We Dem Boyz (Remix) added with success
# 4989408
# songs Welcome 2 My Block (Clinton Sparks RMX) added with success
# 39179
# songs We Live This added with success
# 2452
# songs We Major added with success
# 34871
# songs We March as Millions added with success
# 3944
# songs We’re Not Alone added with success
# 3472
# songs We Will Survive added with success
# 32953
# songs What About Us? (Remix) added with success
# 627
# songs What Goes Around added with success
# 1891
# songs What If added with success
# 776420
# songs What’s Going On (Dupri original mix) added with success
# 3191039
# songs What’s Going On (J. Dupri Original Remix) added with success
# 31721
# songs What’s Going On (J. Dupri R&B Remix) added with success
# 3251744
# songs What’s the Word (Remix) added with success
# 379678
# songs What Type of Nigga added with success
# 34872
# songs What You Gonna Do added with success
# 53515
# songs When Thugs die added with success
# 3331815
# songs Where Am I Going added with success
# 687
# songs Where Are They Now added with success
# 468612
# songs Where Are They Now (80's Remix) added with success
# 468609
# songs Where Are They Now (90's Remix) added with success
# 34878
# songs Where Are They Now? (West Coast Remix) added with success
# 30760
# songs Where Do We Go From Here added with success
# 78873
# songs Where’s The Love added with success
# 3620
# songs Where Y’all At added with success
# 3780017
# songs White Label added with success
# 53063
# songs Who Are You added with success
# 110798
# songs Who Are You (Who I Am) added with success
# 1503
# songs Who Killed It? added with success
# 1713499
# songs Who Killed It? [Clean] added with success
# 7038
# songs Who U Rep With added with success
# 1742
# songs Why (Remix) added with success
# 33002
# songs Why R U? (Remix) added with success
# 44975
# songs Why You Hate the Game added with success
# 1803731
# songs Why You Hate The Game (Exclusive) added with success
# 14282
# songs With Me added with success
# 4560300
# songs Won’t Take My Soul added with success
# 78864
# songs World’s an Addiction added with success
# 2899246
# songs Wrote My Way Out added with success
# 65274
# songs Yacht Music added with success
# 1860557
# songs Y’all My Ni**as added with success
# 3184
# songs Y’all My Niggas added with success
# 488623
# songs Yellow Bird added with success
# 20367
# songs Yes Yes Y’all added with success
# 34797
# songs You Can’t Kill Me added with success
# 2200
# songs You Can’t Stop Us Now added with success
# 34818
# songs You Don’t Know Me added with success
# 15599
# songs You Gonna Luv Me (Remix) added with success
# 34770
# songs You Know My Style added with success
# 22250
# songs You Made Me added with success
# 4672356
# songs You Mean the World to Me added with success
# 5269333
# songs Young Sinatra 1-4 Continuous mix added with success
# 34833
# songs You Owe Me added with success
# 1006056
# songs You Owe Me (feat Ginuwine) added with success
# 1703
# songs You’re da Man added with success
# 5396348
# songs You’re Da Man (Original Version) added with success
# 358439
# songs Your Mouth Got You in It added with success
# 3474
# songs You Won’t See Me Tonight added with success
# 78866
# songs You Wouldn’t Understand added with success
# 3976877
# songs YSIV added with success
# 3002391
# songs Zombies added with success
# 34791
# songs Zone Out added with success

# %%
print(len(songs))
# Out:
# 910

# %%
lk
